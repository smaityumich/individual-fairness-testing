# %%
import numpy as np
seeds = np.load('./seeds.npy')
i = 2
seed_data, seed_model = seeds[i, 0], seeds[i, 1]
lr = 5e-2
filename = f'reduction/outcome/perturbed_ratio_0_to_200_seed_{seed_data}_lr_{lr}.npy'
a = np.load(filename)

# %%
a
# Out:
# array([1.0553569, 1.0596287, 1.0596287, 1.0550982, 1.0553569, 1.0625207,
#        1.0507733, 1.0471617, 1.0597067, 1.0530957, 1.0565546, 1.0634239,
#        1.0526937, 1.0625207, 1.0507733, 1.0597067, 1.0279936, 1.0507733,
#        1.0544807, 1.0578582, 1.0565432, 1.0507733, 1.0480253, 1.0565432,
#        1.0519546, 1.0469396, 1.0553569, 1.0630959, 1.0480253, 1.0500304,
#        1.0528023, 1.0536145, 1.0459327, 1.0319871, 1.0536145, 1.0591128,
#        1.0330337, 1.0277514, 1.0565546, 1.0550982, 1.0537702, 1.0327497,
#        1.0348532, 1.0480162, 1.0507733, 1.0548818, 1.0561545, 1.0507733,
#        1.0553569, 1.0565432, 1.0622411, 1.0577292, 1.0519546, 1.0528023,
#        1.0277514, 1.0526937, 1.0588233, 1.0553569, 1.0536145, 1.0553569,
#        1.063158 , 1.058063 , 1.0507733, 1.0507733, 1.0548818, 1.0600458,
#        1.0536145, 1.0617634, 1.0596287, 1.0596287, 1.0416348, 1.0258759,
#        1.058063 , 1.0573848, 1.0507733, 1.0437988, 1.0597067, 1.0277514,
# ...
